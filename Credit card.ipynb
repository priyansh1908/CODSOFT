# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('/Users/priyanshpatel/Desktop/codsoft/Credit_card/fraudTrain.csv')
df_test = pd.read_csv('/Users/priyanshpatel/Desktop/codsoft/Credit_card/fraudTest.csv')

# %%
df_train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df_train.shape
# Out:
# (1296675, 23)

# %%
df_train.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
gender_count = df_train['gender'].value_counts()
gender_count
# Out:
# F    709863
# M    586812
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(5, 5))
sns.barplot(x=gender_count.index, y=gender_count)
plt.title('Gender distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
df_train['trans_date_trans_time']=pd.to_datetime(df_train['trans_date_trans_time'])

# %%
df_train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df_train['date']=df_train['trans_date_trans_time'].dt.strftime('%d-%m-%Y')

# %%
df_train['date']=pd.to_datetime(df_train['date'])
# Out:
# /var/folders/64/m_40qk0x1s5g07xxhjly0qp00000gn/T/ipykernel_34937/77774989.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_train['date']=pd.to_datetime(df_train['date'])

# %%
df_train['dob']=pd.to_datetime(df_train['dob'])

# %%
df_train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      long city_pop  \
# 0    Banks      F                561 Perry Cove  ...  -81.1781     3495
# ...

# %%
df_train['year'] = df_train['date'].dt.year

# %%
plt.figure(figsize=(5,5))
sns.countplot(data=df_train, x='year', palette='viridis')
plt.title('Year Distribution Plot')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
categorical_features = ['merchant', 'category', 'gender', 'street', 'city', 'state', 'job', 'dob']
for feature in categorical_features:
    df_train[feature] = label_encoder.fit_transform(df_train[feature])

# %%
X = df_train.drop(columns=['is_fraud'])
y = df_train['is_fraud']

# %%
X
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  merchant  \
# 0                 0   2019-01-01 00:00:18     2703186189652095       514
# 1                 1   2019-01-01 00:00:44         630423337322       241
# 2                 2   2019-01-01 00:00:51       38859492057661       390
# 3                 3   2019-01-01 00:01:16     3534093764340240       360
# 4                 4   2019-01-01 00:03:06      375534208663984       297
# ...             ...                   ...                  ...       ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123       499
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997         2
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695       599
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919       509
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207       370
#
#          category     amt        first       last  gender  street  ...  \
# ...

# %%
categorical_features
# Out:
# ['merchant', 'category', 'gender', 'street', 'city', 'state', 'job', 'dob']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train[train_features], y, test_size=0.2, random_state=1)

# %%
train_features=categorical_features
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
regressor = LogisticRegression()
regressor.fit(X_train,y_train)
# Out:
# /Users/priyanshpatel/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
y_pred = regressor.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9944858966202017

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[257905,      0],
#        [  1430,      0]])

# %%
df_test
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
y1_test=df_test['is_fraud']

# %%
le1 = LabelEncoder()
categorical_features1 = ['merchant', 'category', 'gender', 'street', 'city', 'state', 'job', 'dob']
for feature1 in categorical_features1:
    df_test[feature1] = le1.fit_transform(df_test[feature1])

# %%
df_test
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  merchant  \
# 0                0   2020-06-21 12:14:25  2291163933867244       319
# 1                1   2020-06-21 12:14:33  3573030041201292       591
# 2                2   2020-06-21 12:14:53  3598215285024754       611
# 3                3   2020-06-21 12:15:15  3591919803438423       222
# 4                4   2020-06-21 12:15:17  3526826139003047       292
# ...            ...                   ...               ...       ...
# 555714      555714   2020-12-31 23:59:07    30560609640617       507
# 555715      555715   2020-12-31 23:59:09  3556613125071656       264
# 555716      555716   2020-12-31 23:59:15  6011724471098086       496
# 555717      555717   2020-12-31 23:59:24     4079773899158        75
# 555718      555718   2020-12-31 23:59:34  4170689372027579       125
#
#         category     amt    first      last  gender  street  ...      lat  \
# ...

# %%
train_features
# Out:
# ['merchant', 'category', 'gender', 'street', 'city', 'state', 'job', 'dob']

# %%
y_pred1=regressor.predict(df_test[train_features])

# %%
accuracy_score(y1_test, y_pred1)
# Out:
# 0.9961401355721147

# %%
classifier = DecisionTreeClassifier()
classifier.fit(df_train[train_features], y)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=classifier.predict(df_test[train_features])
accuracy_score(y1_test, y_pred2)
# Out:
# 0.972257561825311

# %%
rf = RandomForestClassifier()
rf.fit(df_train[train_features], y)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(df_test[train_features])
accuracy_score(y1_test, y_pred3)
# Out:
# 0.9956236875111342
